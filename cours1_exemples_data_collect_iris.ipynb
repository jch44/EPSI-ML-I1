# %% [markdown]
# # Exemples de fonctions Pandas utiles pour le TP 1

# %% [markdown]
# ## Importations des librairies utiles

# %%
import numpy as np
import pandas as pd
import os
print('numpy %s, pandas %s'%(np.__version__,pd.__version__))
print(os.getcwd())
# Out:
# numpy 1.21.1, pandas 1.3.0
# d:\EPSI\2022\Cours\DIAE505CollecteDonnees\TP

# %% [markdown]
# ## Creation depuis un CSV et affichage d'un Dataframe Pandas

# %%
my_dataframe = pd.read_csv('Data/iris.csv')
my_dataframe
# Out:
#      id_Iris  Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# 0         23                   NaN                  NaN                   1.4
# 1        104                   4.9                  3.0                   1.4
# 2         18                   4.7                  3.2                   1.3
# 3         49                   4.6                  3.1                   1.5
# 4        123                   5.0                  3.6                   1.4
# ..       ...                   ...                  ...                   ...
# 145      124                   6.7                  3.0                   5.2
# 146       44                   6.3                  2.5                   5.0
# 147       69                   6.5                  3.0                   NaN
# 148       56                   6.2                  3.4                   5.4
# 149        5                   5.9                  3.0                   5.1
#
#      Largeur Pétale (cm)  Type Iris
# 0                    0.2          0
# 1                    0.2          0
# 2                    0.2          0
# 3                    0.2          0
# 4                    0.2          0
# ..                   ...        ...
# 145                  2.3          2
# 146                  1.9          2
# 147                  2.0          2
# 148                  2.3          2
# 149                  1.8          2
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Transformation de l'ID en index

# %%
my_dataframe.set_index('id_Iris',inplace=True)
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 23                        NaN                  NaN                   1.4
# 104                       4.9                  3.0                   1.4
# 18                        4.7                  3.2                   1.3
# 49                        4.6                  3.1                   1.5
# 123                       5.0                  3.6                   1.4
# ...                       ...                  ...                   ...
# 124                       6.7                  3.0                   5.2
# 44                        6.3                  2.5                   5.0
# 69                        6.5                  3.0                   NaN
# 56                        6.2                  3.4                   5.4
# 5                         5.9                  3.0                   5.1
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 23                       0.2          0
# 104                      0.2          0
# 18                       0.2          0
# 49                       0.2          0
# 123                      0.2          0
# ...                      ...        ...
# 124                      2.3          2
# 44                       1.9          2
# 69                       2.0          2
# 56                       2.3          2
# 5                        1.8          2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Tri selon l'index

# %%
my_dataframe.sort_index(inplace=True) #Inplace permet de conserver les modification du DataFrame
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 0                        0.2          0
# 1                        0.2          0
# 2                        1.4          1
# 3                        0.2          0
# 4                        1.3          1
# ...                      ...        ...
# 145                      1.5          1
# 146                      1.0          1
# 147                      0.3          0
# 148                      1.8          2
# 149                      2.3          2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Exploration des données

# %%
my_dataframe.sample(5)
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 121                       5.9                  3.2                   4.8
# 146                       6.0                  2.2                   4.0
# 0                         4.9                  3.1                   1.5
# 7                         5.4                  3.4                   1.7
# 107                       5.2                  2.7                   3.9
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 121                      1.8          1
# 146                      1.0          1
# 0                        0.2          0
# 7                        0.2          0
# 107                      1.4          1

# %%
my_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Longueur Sépale (cm)  142 non-null    float64
#  1   Largeur Sépale (cm)   142 non-null    float64
#  2   Longueur Pétale (cm)  143 non-null    float64
#  3   Largeur Pétale (cm)   146 non-null    float64
#  4   Type Iris             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 7.0 KB

# %%
my_dataframe.dtypes
# Out:
# Longueur Sépale (cm)    float64
# Largeur Sépale (cm)     float64
# Longueur Pétale (cm)    float64
# Largeur Pétale (cm)     float64
# Type Iris                 int64
# dtype: object

# %%
my_dataframe.describe()
# Out:
#        Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# count            142.000000           142.000000            143.000000
# mean               5.846479             3.049296              3.756643
# std                0.840184             0.440784              1.748140
# min                4.300000             2.000000              1.000000
# 25%                5.100000             2.800000              1.600000
# 50%                5.800000             3.000000              4.300000
# 75%                6.400000             3.300000              5.100000
# max                7.900000             4.400000              6.900000
#
#        Largeur Pétale (cm)   Type Iris
# count           146.000000  150.000000
# mean              1.208219    1.000000
# std               0.762709    0.819232
# min               0.100000    0.000000
# 25%               0.300000    0.000000
# 50%               1.300000    1.000000
# 75%               1.800000    2.000000
# max               2.500000    2.000000

# %% [markdown]
# ## Filtrage des données

# %%
my_dataframe.boxplot(fontsize=12, figsize=(18,10))
# Out:
# <AxesSubplot:>

# %%
# filtered_dataframe
exclusion_outliers = my_dataframe["Largeur Sépale (cm)"].between(2.1,4)
print("Total:",len(exclusion_outliers), "Conservés:", exclusion_outliers.sum())
filtered_dataframe =  my_dataframe[exclusion_outliers]
filtered_dataframe.boxplot(fontsize=12, figsize=(18,10))
# Out:
# Total: 150 Conservés: 138
# <AxesSubplot:>

# %% [markdown]
# ## Gestion des données manquantes
# ### Création d'un petit Dataframe avec des données manquantes dans "Longueur Sépale"

# %%
# Sélection des Iris avec Longueur Sépale indéfinie
small_df_na = my_dataframe[my_dataframe['Longueur Sépale (cm)'].isna()]
# Sélection aléatoire des Iris avec Longueur Sépale définie
small_df_rnd = my_dataframe[~my_dataframe['Longueur Sépale (cm)'].isna()].sample(20, random_state=42)
my_dataframe[my_dataframe['Longueur Sépale (cm)'].isna()]
small_df = pd.concat([small_df_na,small_df_rnd]).sort_index()
small_df
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 12                        5.5                  4.2                   1.4
# 18                        4.7                  3.2                   1.3
# 19                        NaN                  2.6                   4.0
# 20                        5.2                  4.1                   1.5
# 23                        NaN                  NaN                   1.4
# 29                        6.7                  3.1                   5.6
# 33                        NaN                  3.1                   4.9
# 42                        NaN                  2.7                   5.1
# 48                        NaN                  3.7                   1.5
# 56                        6.2                  3.4                   5.4
# 61                        6.9                  3.1                   5.4
# 69                        6.5                  3.0                   NaN
# 70                        6.0                  3.4                   4.5
# 71                        5.1                  NaN                   1.6
# 74                        5.6                  2.9                   3.6
# 78                        4.7                  3.2                   1.6
# 82                        6.2                  2.8                   4.8
# 86                        6.7                  NaN                   5.7
# 98                        5.9                  3.0                   4.2
# 101                       6.2                  2.9                   4.3
# 103                       7.4                  2.8                   6.1
# 112                       NaN                  3.3                   6.0
# 121                       5.9                  3.2                   4.8
# 130                       5.5                  2.5                   4.0
# 136                       7.7                  3.8                   6.7
# 137                       4.9                  2.5                   4.5
# 141                       NaN                  2.7                   4.2
# 144                       NaN                  3.5                   1.3
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 12                       0.2          0
# 18                       0.2          0
# 19                       1.2          1
# 20                       0.1          0
# 23                       0.2          0
# 29                       2.4          2
# 33                       1.5          1
# 42                       1.6          1
# 48                       0.4          0
# 56                       2.3          2
# 61                       2.1          2
# 69                       2.0          2
# 70                       1.6          1
# 71                       0.2          0
# 74                       1.3          1
# 78                       0.2          0
# 82                       1.8          2
# 86                       2.5          2
# 98                       1.5          1
# 101                      1.3          1
# 103                      1.9          2
# 112                      2.5          2
# 121                      1.8          1
# 130                      1.3          1
# 136                      2.2          2
# 137                      1.7          2
# 141                      1.3          1
# 144                      0.2          0

# %% [markdown]
# ### Suppression des lignes avec des données manquantes

# %%
small_df[~small_df.isna().any(axis=1)]
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 12                        5.5                  4.2                   1.4
# 18                        4.7                  3.2                   1.3
# 20                        5.2                  4.1                   1.5
# 29                        6.7                  3.1                   5.6
# 56                        6.2                  3.4                   5.4
# 61                        6.9                  3.1                   5.4
# 70                        6.0                  3.4                   4.5
# 74                        5.6                  2.9                   3.6
# 78                        4.7                  3.2                   1.6
# 82                        6.2                  2.8                   4.8
# 98                        5.9                  3.0                   4.2
# 101                       6.2                  2.9                   4.3
# 103                       7.4                  2.8                   6.1
# 121                       5.9                  3.2                   4.8
# 130                       5.5                  2.5                   4.0
# 136                       7.7                  3.8                   6.7
# 137                       4.9                  2.5                   4.5
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 12                       0.2          0
# 18                       0.2          0
# 20                       0.1          0
# 29                       2.4          2
# 56                       2.3          2
# 61                       2.1          2
# 70                       1.6          1
# 74                       1.3          1
# 78                       0.2          0
# 82                       1.8          2
# 98                       1.5          1
# 101                      1.3          1
# 103                      1.9          2
# 121                      1.8          1
# 130                      1.3          1
# 136                      2.2          2
# 137                      1.7          2

# %% [markdown]
# ### Suppression d'une colonne

# %%
small_df.drop('Longueur Sépale (cm)', axis=1)
# Out:
#          Largeur Sépale (cm)  Longueur Pétale (cm)  Largeur Pétale (cm)  \
# id_Iris
# 12                       4.2                   1.4                  0.2
# 18                       3.2                   1.3                  0.2
# 19                       2.6                   4.0                  1.2
# 20                       4.1                   1.5                  0.1
# 23                       NaN                   1.4                  0.2
# 29                       3.1                   5.6                  2.4
# 33                       3.1                   4.9                  1.5
# 42                       2.7                   5.1                  1.6
# 48                       3.7                   1.5                  0.4
# 56                       3.4                   5.4                  2.3
# 61                       3.1                   5.4                  2.1
# 69                       3.0                   NaN                  2.0
# 70                       3.4                   4.5                  1.6
# 71                       NaN                   1.6                  0.2
# 74                       2.9                   3.6                  1.3
# 78                       3.2                   1.6                  0.2
# 82                       2.8                   4.8                  1.8
# 86                       NaN                   5.7                  2.5
# 98                       3.0                   4.2                  1.5
# 101                      2.9                   4.3                  1.3
# 103                      2.8                   6.1                  1.9
# 112                      3.3                   6.0                  2.5
# 121                      3.2                   4.8                  1.8
# 130                      2.5                   4.0                  1.3
# 136                      3.8                   6.7                  2.2
# 137                      2.5                   4.5                  1.7
# 141                      2.7                   4.2                  1.3
# 144                      3.5                   1.3                  0.2
#
#          Type Iris
# id_Iris
# 12               0
# 18               0
# 19               1
# 20               0
# 23               0
# 29               2
# 33               1
# 42               1
# 48               0
# 56               2
# 61               2
# 69               2
# 70               1
# 71               0
# 74               1
# 78               0
# 82               2
# 86               2
# 98               1
# 101              1
# 103              2
# 112              2
# 121              1
# 130              1
# 136              2
# 137              2
# 141              1
# 144              0

# %% [markdown]
# ### Remplacement par la moyenne

# %%
fulfilled_small_df=small_df.copy()
fulfilled_small_df["Longueur Sépale (cm)"] = fulfilled_small_df["Longueur Sépale (cm)"].fillna(small_df["Longueur Sépale (cm)"].mean())
fulfilled_small_df
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 12                      5.500                  4.2                   1.4
# 18                      4.700                  3.2                   1.3
# 19                      5.975                  2.6                   4.0
# 20                      5.200                  4.1                   1.5
# 23                      5.975                  NaN                   1.4
# 29                      6.700                  3.1                   5.6
# 33                      5.975                  3.1                   4.9
# 42                      5.975                  2.7                   5.1
# 48                      5.975                  3.7                   1.5
# 56                      6.200                  3.4                   5.4
# 61                      6.900                  3.1                   5.4
# 69                      6.500                  3.0                   NaN
# 70                      6.000                  3.4                   4.5
# 71                      5.100                  NaN                   1.6
# 74                      5.600                  2.9                   3.6
# 78                      4.700                  3.2                   1.6
# 82                      6.200                  2.8                   4.8
# 86                      6.700                  NaN                   5.7
# 98                      5.900                  3.0                   4.2
# 101                     6.200                  2.9                   4.3
# 103                     7.400                  2.8                   6.1
# 112                     5.975                  3.3                   6.0
# 121                     5.900                  3.2                   4.8
# 130                     5.500                  2.5                   4.0
# 136                     7.700                  3.8                   6.7
# 137                     4.900                  2.5                   4.5
# 141                     5.975                  2.7                   4.2
# 144                     5.975                  3.5                   1.3
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 12                       0.2          0
# 18                       0.2          0
# 19                       1.2          1
# 20                       0.1          0
# 23                       0.2          0
# 29                       2.4          2
# 33                       1.5          1
# 42                       1.6          1
# 48                       0.4          0
# 56                       2.3          2
# 61                       2.1          2
# 69                       2.0          2
# 70                       1.6          1
# 71                       0.2          0
# 74                       1.3          1
# 78                       0.2          0
# 82                       1.8          2
# 86                       2.5          2
# 98                       1.5          1
# 101                      1.3          1
# 103                      1.9          2
# 112                      2.5          2
# 121                      1.8          1
# 130                      1.3          1
# 136                      2.2          2
# 137                      1.7          2
# 141                      1.3          1
# 144                      0.2          0

# %% [markdown]
# ### Interpolation linéaire

# %% [markdown]
# ### Régression linéaire entre Longueur Sépale et Longueur Pétale

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

filter_not_nan = ~(small_df['Longueur Sépale (cm)'].isnull() | small_df['Longueur Pétale (cm)'].isnull())
x = small_df.loc[filter_not_nan,'Longueur Pétale (cm)'].values.reshape(-1, 1) # Mise au format pour le fit, car plusieurs variables possibles
print(x)
y = small_df.loc[filter_not_nan,'Longueur Sépale (cm)']
model = LinearRegression()

model.fit(x,y)
y_predict = model.predict(x)

plt.scatter(x, y)
plt.plot(x, y_predict, color='g')
plt.show()
# Out:
# [[1.4]
#  [1.3]
#  [1.5]
#  [5.6]
#  [5.4]
#  [5.4]
#  [4.5]
#  [1.6]
#  [3.6]
#  [1.6]
#  [4.8]
#  [5.7]
#  [4.2]
#  [4.3]
#  [6.1]
#  [4.8]
#  [4. ]
#  [6.7]
#  [4.5]]

# %%
x_reg = small_df.loc[small_df['Longueur Sépale (cm)'].isnull() ,'Longueur Pétale (cm)'].values.reshape(-1, 1)
y_reg = model.predict(x_reg)

# %% [markdown]
# ### Affichage des points calculé par régression linéaire

# %%
plt.scatter(x, y)
plt.scatter(x_reg, y_reg, color='r')
plt.plot(x, y_predict, color='g')
plt.show()
fulfilled_small_df.loc[small_df['Longueur Sépale (cm)'].isnull() ,'Longueur Sépale (cm)'] = y_reg
fulfilled_small_df
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 12                   5.500000                  4.2                   1.4
# 18                   4.700000                  3.2                   1.3
# 19                   5.925080                  2.6                   4.0
# 20                   5.200000                  4.1                   1.5
# 23                   4.824010                  NaN                   1.4
# 29                   6.700000                  3.1                   5.6
# 33                   6.306219                  3.1                   4.9
# 42                   6.390917                  2.7                   5.1
# 48                   4.866359                  3.7                   1.5
# 56                   6.200000                  3.4                   5.4
# 61                   6.900000                  3.1                   5.4
# 69                   6.500000                  3.0                   NaN
# 70                   6.000000                  3.4                   4.5
# 71                   5.100000                  NaN                   1.6
# 74                   5.600000                  2.9                   3.6
# 78                   4.700000                  3.2                   1.6
# 82                   6.200000                  2.8                   4.8
# 86                   6.700000                  NaN                   5.7
# 98                   5.900000                  3.0                   4.2
# 101                  6.200000                  2.9                   4.3
# 103                  7.400000                  2.8                   6.1
# 112                  6.772056                  3.3                   6.0
# 121                  5.900000                  3.2                   4.8
# 130                  5.500000                  2.5                   4.0
# 136                  7.700000                  3.8                   6.7
# 137                  4.900000                  2.5                   4.5
# 141                  6.009777                  2.7                   4.2
# 144                  4.781661                  3.5                   1.3
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 12                       0.2          0
# 18                       0.2          0
# 19                       1.2          1
# 20                       0.1          0
# 23                       0.2          0
# 29                       2.4          2
# 33                       1.5          1
# 42                       1.6          1
# 48                       0.4          0
# 56                       2.3          2
# 61                       2.1          2
# 69                       2.0          2
# 70                       1.6          1
# 71                       0.2          0
# 74                       1.3          1
# 78                       0.2          0
# 82                       1.8          2
# 86                       2.5          2
# 98                       1.5          1
# 101                      1.3          1
# 103                      1.9          2
# 112                      2.5          2
# 121                      1.8          1
# 130                      1.3          1
# 136                      2.2          2
# 137                      1.7          2
# 141                      1.3          1
# 144                      0.2          0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Création de catégories pour les tailles et ajour du nom de l'iris

# %%
for taille in ["Longueur Sépale (cm)","Largeur Sépale (cm)","Longueur Pétale (cm)","Largeur Pétale (cm)"]:
    my_dataframe[taille.replace(" (cm)","")] = pd.qcut(my_dataframe[taille],3,['petit','moyen','grand'])
my_dataframe['Nom Iris'] = my_dataframe['Type Iris'].map({
    0:'Versicolor',
    1:'Setosa',
    2:'Virginica',
})
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris Longueur Sépale Largeur Sépale  \
# id_Iris
# 0                        0.2          0           petit          moyen
# 1                        0.2          0           petit          grand
# 2                        1.4          1           grand          moyen
# 3                        0.2          0           petit          moyen
# 4                        1.3          1           moyen            NaN
# ...                      ...        ...             ...            ...
# 145                      1.5          1           grand          petit
# 146                      1.0          1           moyen          petit
# 147                      0.3          0           petit          grand
# 148                      1.8          2           grand          petit
# 149                      2.3          2           grand          moyen
#
#         Longueur Pétale Largeur Pétale    Nom Iris
# id_Iris
# 0                 petit          petit  Versicolor
# 1                 petit          petit  Versicolor
# 2                 moyen          moyen      Setosa
# 3                 petit          petit  Versicolor
# 4                 moyen          moyen      Setosa
# ...                 ...            ...         ...
# 145               moyen          moyen      Setosa
# 146               moyen          petit      Setosa
# 147               petit          petit  Versicolor
# 148                 NaN          grand   Virginica
# 149               grand          grand   Virginica
#
# [150 rows x 10 columns]

# %% [markdown]
# ### Distribution des labels selon une feature

# %%
display(pd.crosstab(my_dataframe["Longueur Pétale"],my_dataframe["Nom Iris"]))
print("-"*50)
display(pd.crosstab(my_dataframe["Largeur Sépale"],my_dataframe["Nom Iris"]))
# Out:
# Nom Iris         Setosa  Versicolor  Virginica
# Longueur Pétale
# petit                 1          47          0
# moyen                44           0          3
# grand                 4           0         44
# --------------------------------------------------
# Nom Iris        Setosa  Versicolor  Virginica
# Largeur Sépale
# petit               32           1         21
# moyen               14          15         19
# grand                2          31          7

# %% [markdown]
# ### Information Mutuelle

# %%
from sklearn.feature_selection import mutual_info_regression

studied_features = ["Longueur Sépale","Largeur Sépale","Longueur Pétale","Largeur Pétale"]
X = my_dataframe[studied_features].copy()
for colname in X.columns:
    X[colname], _ = X[colname].factorize() # transforme des catégories en nombre entier

discrete_features = X.dtypes == "int64"

mi_scores = mutual_info_regression(
    X, 
    my_dataframe['Type Iris'],
    discrete_features = discrete_features    
)
mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
mi_scores = mi_scores.sort_values(ascending=False)
mi_scores
# Out:
# Longueur Pétale    0.850263
# Largeur Pétale     0.786663
# Longueur Sépale    0.394689
# Largeur Sépale     0.165637
# Name: MI Scores, dtype: float64

# %%
scores = mi_scores.sort_values(ascending=True)
width = np.arange(len(scores))
ticks = list(scores.index)
plt.barh(width, scores)
plt.yticks(width, ticks)
plt.title("Mutual Information Scores")
# Out:
# Text(0.5, 1.0, 'Mutual Information Scores')

# %% [markdown]
# ### compter des conditions (nombre de grande dimension)

# %%
discrete_features = ["Longueur Sépale","Largeur Sépale","Longueur Pétale","Largeur Pétale"]
my_dataframe["nbGrand"] = (my_dataframe[discrete_features]=="grand").sum(axis=1)
display(pd.crosstab(my_dataframe["nbGrand"],my_dataframe["Nom Iris"]))
my_dataframe.sample(5, random_state=42)
# Out:
# Nom Iris  Setosa  Versicolor  Virginica
# nbGrand
# 0             34          19          0
# 1             15          31          7
# 2              0           0         13
# 3              1           0         26
# 4              0           0          4
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 73                        5.4                  3.9                   1.7
# 18                        4.7                  3.2                   1.3
# 118                       6.7                  3.0                   5.0
# 78                        4.7                  3.2                   1.6
# 76                        5.1                  3.5                   1.4
#
#          Largeur Pétale (cm)  Type Iris Longueur Sépale Largeur Sépale  \
# id_Iris
# 73                       0.4          0           petit          grand
# 18                       0.2          0           petit          moyen
# 118                      1.7          1           grand          moyen
# 78                       0.2          0           petit          moyen
# 76                       0.3          0           petit          grand
#
#         Longueur Pétale Largeur Pétale    Nom Iris  nbGrand
# id_Iris
# 73                petit          petit  Versicolor        1
# 18                petit          petit  Versicolor        0
# 118               grand          grand      Setosa        3
# 78                petit          petit  Versicolor        0
# 76                petit          petit  Versicolor        1

# %% [markdown]
# ### Group & Transform : Ajouter la largeur moyenne de la pétale en fonction de sa catégorie de longueur

# %%
my_dataframe["Moy Largeur Pétale"] = (
    my_dataframe.groupby("Longueur Pétale")  # for each state
    ["Largeur Pétale (cm)"]                 # select the income
    .transform("mean")         # and compute its mean
)
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris Longueur Sépale Largeur Sépale  \
# id_Iris
# 0                        0.2          0           petit          moyen
# 1                        0.2          0           petit          grand
# 2                        1.4          1           grand          moyen
# 3                        0.2          0           petit          moyen
# 4                        1.3          1           moyen            NaN
# ...                      ...        ...             ...            ...
# 145                      1.5          1           grand          petit
# 146                      1.0          1           moyen          petit
# 147                      0.3          0           petit          grand
# 148                      1.8          2           grand          petit
# 149                      2.3          2           grand          moyen
#
#         Longueur Pétale Largeur Pétale    Nom Iris  nbGrand  \
# id_Iris
# 0                 petit          petit  Versicolor        0
# 1                 petit          petit  Versicolor        1
# 2                 moyen          moyen      Setosa        1
# 3                 petit          petit  Versicolor        0
# 4                 moyen          moyen      Setosa        0
# ...                 ...            ...         ...      ...
# 145               moyen          moyen      Setosa        1
# 146               moyen          petit      Setosa        0
# 147               petit          petit  Versicolor        1
# 148                 NaN          grand   Virginica        2
# 149               grand          grand   Virginica        3
#
#          Moy Largeur Pétale
# id_Iris
# 0                  0.260870
# 1                  0.260870
# 2                  1.336957
# 3                  0.260870
# 4                  1.336957
# ...                     ...
# 145                1.336957
# 146                1.336957
# 147                0.260870
# 148                     NaN
# 149                2.008511
#
# [150 rows x 12 columns]

# %% [markdown]
# ## Target Encoding

# %% [markdown]
# #### Sans lissage

# %%
my_dataframe["Moy Type Iris"] = (
    my_dataframe.groupby("Longueur Pétale")  # for each state
    ["Type Iris"]                 # select the income
    .transform("mean")         # and compute its mean
)
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris Longueur Sépale Largeur Sépale  \
# id_Iris
# 0                        0.2          0           petit          moyen
# 1                        0.2          0           petit          grand
# 2                        1.4          1           grand          moyen
# 3                        0.2          0           petit          moyen
# 4                        1.3          1           moyen            NaN
# ...                      ...        ...             ...            ...
# 145                      1.5          1           grand          petit
# 146                      1.0          1           moyen          petit
# 147                      0.3          0           petit          grand
# 148                      1.8          2           grand          petit
# 149                      2.3          2           grand          moyen
#
#         Longueur Pétale Largeur Pétale    Nom Iris  nbGrand  \
# id_Iris
# 0                 petit          petit  Versicolor        0
# 1                 petit          petit  Versicolor        1
# 2                 moyen          moyen      Setosa        1
# 3                 petit          petit  Versicolor        0
# 4                 moyen          moyen      Setosa        0
# ...                 ...            ...         ...      ...
# 145               moyen          moyen      Setosa        1
# 146               moyen          petit      Setosa        0
# 147               petit          petit  Versicolor        1
# 148                 NaN          grand   Virginica        2
# 149               grand          grand   Virginica        3
#
#          Moy Largeur Pétale  Moy Type Iris
# id_Iris
# 0                  0.260870       0.020833
# 1                  0.260870       0.020833
# 2                  1.336957       1.063830
# 3                  0.260870       0.020833
# 4                  1.336957       1.063830
# ...                     ...            ...
# 145                1.336957       1.063830
# 146                1.336957       1.063830
# 147                0.260870       0.020833
# 148                     NaN            NaN
# 149                2.008511       1.916667
#
# [150 rows x 13 columns]

# %% [markdown]
# ### Avec Lissage

# %%
# Facteur de lissage = 100
coef = 150/(150 + 100)
my_dataframe["Moy Type Iris"] = coef * my_dataframe["Moy Type Iris"] + (1-coef) * my_dataframe["Type Iris"].mean()
my_dataframe["Moy Type Iris"]
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris Longueur Sépale Largeur Sépale  \
# id_Iris
# 0                        0.2          0           petit          moyen
# 1                        0.2          0           petit          grand
# 2                        1.4          1           grand          moyen
# 3                        0.2          0           petit          moyen
# 4                        1.3          1           moyen            NaN
# ...                      ...        ...             ...            ...
# 145                      1.5          1           grand          petit
# 146                      1.0          1           moyen          petit
# 147                      0.3          0           petit          grand
# 148                      1.8          2           grand          petit
# 149                      2.3          2           grand          moyen
#
#         Longueur Pétale Largeur Pétale    Nom Iris  nbGrand  \
# id_Iris
# 0                 petit          petit  Versicolor        0
# 1                 petit          petit  Versicolor        1
# 2                 moyen          moyen      Setosa        1
# 3                 petit          petit  Versicolor        0
# 4                 moyen          moyen      Setosa        0
# ...                 ...            ...         ...      ...
# 145               moyen          moyen      Setosa        1
# 146               moyen          petit      Setosa        0
# 147               petit          petit  Versicolor        1
# 148                 NaN          grand   Virginica        2
# 149               grand          grand   Virginica        3
#
#          Moy Largeur Pétale  Moy Type Iris
# id_Iris
# 0                  0.260870       0.412500
# 1                  0.260870       0.412500
# 2                  1.336957       1.038298
# 3                  0.260870       0.412500
# 4                  1.336957       1.038298
# ...                     ...            ...
# 145                1.336957       1.038298
# 146                1.336957       1.038298
# 147                0.260870       0.412500
# 148                     NaN            NaN
# 149                2.008511       1.550000
#
# [150 rows x 13 columns]
